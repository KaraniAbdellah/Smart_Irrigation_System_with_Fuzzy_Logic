# %%
# Fuzzification
# Infrence
## Agregation
# Deffuzification

# %%
# Discover Your Path Based on Questions and Response
# This for students that get BAC and want to know wich path good.
# QUESTIONS CATEGORY: [FROM First Year in Lycee to Last Year]
# QUESTIONS: [QCMS]


# NOTES [THREE YEARS {S1 + S2} + QCM]
# OUTPUT: [SCEINCE {MATH, INFO, PHYSICS, CHIMIC, BIOLOGIE} OR ART [ISLIMIYATE, IJIMA3iYATE, ...]]

# I need to know how i can get the data
# what type of data i need
# how we can mesure students
